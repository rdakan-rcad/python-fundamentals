# %% [markdown]
# <a href="https://colab.research.google.com/github/rdakan-rcad/python-fundamentals/blob/main/day01_quiz_engine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Start with a list of topics
topics = ["lists", "dictionaries", "loops"]

# Try these one at a time and predict what happens:
print(len(topics))

print("lists" in topics)
print("functions" in topics)

topics.append("functions")
print(topics)

topics.remove("loops")
print(topics)
# Out:
# 3
# True
# False
# ['lists', 'dictionaries', 'loops', 'functions']
# ['lists', 'dictionaries', 'functions']

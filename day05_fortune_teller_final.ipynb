# %% [markdown]
# <a href="https://colab.research.google.com/github/rdakan-rcad/python-fundamentals/blob/main/day05_fortune_teller_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import time

love_answers = ["Romance is in your future", "Guard your heart", "Love will find you"]
money_answers = ["Wealth awaits", "Save your coins", "A windfall approaches"]
general_answers = ["Yes", "No", "Maybe", "The future is unclear"]

print("🔮 WELCOME TO THE FORTUNE TELLER 🔮")
print("=" * 35)

name = input("What is your name? ").strip()
print(f"\nAh, {name}... I have been expecting you.")
print("Type 'quit' when you wish to leave.\n")

time.sleep(1)

while True:
    question = input(f"{name}, ask your question: ").lower()

    if question == "quit":
        print(f"\nFarewell, {name}. May the fates be kind to you...")
        break

    print("The mists swirl...")
    time.sleep(2)

    if "love" in question:
        print(f"The Fortune Teller says: {random.choice(love_answers)}")
    elif "money" in question:
        print(f"The Fortune Teller says: {random.choice(money_answers)}")
    else:
        print(f"The Fortune Teller says: {random.choice(general_answers)}")

    print()
# Out:
# 🔮 WELCOME TO THE FORTUNE TELLER 🔮
# ...
# What is your name? Rick
#
# Ah, Rick... I have been expecting you.
# Type 'quit' when you wish to leave.
#
# Rick, ask your question: What money?
# The mists swirl...
# The Fortune Teller says: Wealth awaits
#
# Rick, ask your question: Quit
#
# Farewell, Rick. May the fates be kind to you...

# %%
print("Line one")
print("Line two")
print("This shows a newline: \\n")
# Out:
# Line one
# Line two
# This shows a newline: \n

# %%
name = input("Before we begin, what is your name? ")
print(f"Welcome, {name}. The spirits are ready for you.")
# Out:
# Before we begin, what is your name? Rick
# Welcome, Rick. The spirits are ready for you.

# %%
print("=" * 35)
print("-" * 10)
print("ha" * 5)
# Out:
# ...
# ----------
# hahahahaha

# %%
import random
import time

love_answers = ["Romance is in your future", "Guard your heart", "Love will find you"]
money_answers = ["Wealth awaits", "Save your coins", "A windfall approaches"]
general_answers = ["Yes", "No", "Maybe", "The future is unclear"]

print("🔮 Welcome to the Fortune Teller!")
print("Type 'quit' to leave.\n")

while True:
    question = input("Ask your question: ").lower()

    if question == "quit":
        print("The Fortune Teller fades into the mist...")
        break

    print("The mists swirl...")
    time.sleep(2)

    if "love" in question:
        print(f"The Fortune Teller says: {random.choice(love_answers)}")
    elif "money" in question:
        print(f"The Fortune Teller says: {random.choice(money_answers)}")
    else:
        print(f"The Fortune Teller says: {random.choice(general_answers)}")

    print()  # blank line between questions
# Out:
# 🔮 Welcome to the Fortune Teller!
# Type 'quit' to leave.
#
# Ask your question: LovE?
# The mists swirl...
# The Fortune Teller says: Romance is in your future
#
# Ask your question: Money?
# The mists swirl...
# The Fortune Teller says: A windfall approaches
#
# Ask your question: Fame?
# The mists swirl...
# The Fortune Teller says: No
#
# Ask your question: QUIT
# The Fortune Teller fades into the mist...

# %%
question = input("Ask a question: ").lower()

if "love" in question:
    print("Ah, a question of the heart...")
elif "money" in question:
    print("You seek fortune and wealth...")
else:
    print("The spirits consider your question...")
# Out:
# Ask a question: LOVE?
# Ah, a question of the heart...

# %%
count = 1

while count <= 5:
    print(f"Count is: {count}")
    count = count + 1
# Out:
# Count is: 1
# Count is: 2
# Count is: 3
# Count is: 4
# Count is: 5

# %%
while True:
    question = input("Ask a question (or type 'quit' to exit): ").lower()
    if question == "quit":
        break
    print(f"You asked: {question}")
# Out:
# Ask a question (or type 'quit' to exit): vfas
# You asked: vfas
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-166760260.py in <cell line: 0>()
#       1 while True:
# ----> 2     question = input("Ask a question (or type 'quit' to exit): ").lower()
#       3     if question == "quit":
#       4         break
#       5     print(f"You asked: {question}")
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %%
import random
import time

love_answers = ["Romance is in your future", "Guard your heart", "Love will find you"]
money_answers = ["Wealth awaits", "Save your coins", "A windfall approaches"]
general_answers = ["Yes", "No", "Maybe", "The future is unclear"]

question = input("🔮 Ask the Fortune Teller: ").lower()

print("The mists swirl...")
time.sleep(2)

if "love" in question:
    print(f"The Fortune Teller says: {random.choice(love_answers)}")
elif "money" in question:
    print(f"The Fortune Teller says: {random.choice(money_answers)}")
else:
    print(f"The Fortune Teller says: {random.choice(general_answers)}")
# Out:
# 🔮 Ask the Fortune Teller: fame?
# The mists swirl...
# The Fortune Teller says: Yes

# %%
print("Hello, I'm Learning Python!")
# Out:
# Hello, I'm Learning Python!

# %%
mood = "ugh"

if mood == "happy":
    print("😊")
elif mood == "sad":
    print("😢")
elif mood == "angry":
    print("😠")
else:
    print("🤷")
# Out:
# 🤷

# %%
question = "Will I learn Python?"
answer = "Yes, definitely."

print(question)
print(answer)
# Out:
# Will I learn Python?
# Yes, definitely.

# %%
question = input("Ask the Fortune Teller a question: ")
print("You asked: " + question)
# Out:
# Ask the Fortune Teller a question: How?
# You asked: How?

# %%
import random

answers = ["Yes", "No", "Maybe", "Ask again later"]
print(random.choice(answers))
# Out:
# Ask again later

# %%
import random

answers = ["Yes", "No", "Maybe", "Ask again later", "Definitely", "I doubt it"]

question = input("🔮 Ask the Fortune Teller a question: ")
print("You asked: " + question)
print("The Fortune Teller says: " +random.choice(answers))
# Out:
# 🔮 Ask the Fortune Teller a question: Why
# You asked: Why
# The Fortune Teller says: Definitely

# %%
import time

print("the Fortune Teller gazes into the crystal ball...")
time.sleep(2)
print("The mists begin to swirl...")
time.sleep(2)
print("A vision emerges!")
# Out:
# the Fortune Teller gaces into the crystal ball...
# The mists begin to swirl...
# A vision emerges!

# %%
import random
import time

answers = ["Danger lurks ahead", "Someone you trust will betray you", "There's no turning back now", "I forsee doom!"]

question = input("🔮 Ask the Fortune Teller a question: ")

print("The Fortune Teller gazes into the crystal ball...")
time.sleep(2)
print("The mists begin to swirl...")
time.sleep(2)
print(f"A vision emerges about: {question}")
time.sleep(1)
print(f"The Fortune Teller says: {random.choice(answers)}")
# Out:
# 🔮 Ask the Fortune Teller a question: jiojo
# The Fortune Teller gazes into the crystal ball...
# The mists begin to swirl...
# A vision emerges about: jiojo
# The Fortune Teller says: Someone you trust will betray you

# %%
name = "Rick"
print(f"Hello, {name}!")
# Out:
# Hello, Rick!

# %% [markdown]
# <a href="https://colab.research.google.com/github/rdakan-rcad/python-fundamentals/blob/main/day01_hello_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, I'm Learning Python!")
# Out:
# Hello, I'm Learning Python!

# %%
question = "Will I learn Python?"
answer = "Yes, definitely."

print(question)
print(answer)
# Out:
# Will I learn Python?
# Yes, definitely.

# %%
question = input("Ask the Fortune Teller a question: ")
print("You asked: " + question)
# Out:
# Ask the Fortune Teller a question: How?
# You asked: How?

# %%
import random

answers = ["Yes", "No", "Maybe", "Ask again later"]
print(random.choice(answers))
# Out:
# Ask again later

# %%
import random

answers = ["Yes", "No", "Maybe", "Ask again later", "Definitely", "I doubt it"]

question = input("🔮 Ask the Fortune Teller a question: ")
print("You asked: " + question)
print("The Fortune Teller says: " +random.choice(answers))
# Out:
# 🔮 Ask the Fortune Teller a question: Why
# You asked: Why
# The Fortune Teller says: Definitely

# %% [markdown]
# <a href="https://colab.research.google.com/github/rdakan-rcad/python-fundamentals/blob/main/day02_fortune_teller_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, I'm Learning Python!")
# Out:
# Hello, I'm Learning Python!

# %%
question = "Will I learn Python?"
answer = "Yes, definitely."

print(question)
print(answer)
# Out:
# Will I learn Python?
# Yes, definitely.

# %%
question = input("Ask the Fortune Teller a question: ")
print("You asked: " + question)
# Out:
# Ask the Fortune Teller a question: How?
# You asked: How?

# %%
import random

answers = ["Yes", "No", "Maybe", "Ask again later"]
print(random.choice(answers))
# Out:
# Ask again later

# %%
import random

answers = ["Yes", "No", "Maybe", "Ask again later", "Definitely", "I doubt it"]

question = input("🔮 Ask the Fortune Teller a question: ")
print("You asked: " + question)
print("The Fortune Teller says: " +random.choice(answers))
# Out:
# 🔮 Ask the Fortune Teller a question: Why
# You asked: Why
# The Fortune Teller says: Definitely

# %%
import time

print("the Fortune Teller gazes into the crystal ball...")
time.sleep(2)
print("The mists begin to swirl...")
time.sleep(2)
print("A vision emerges!")
# Out:
# the Fortune Teller gaces into the crystal ball...
# The mists begin to swirl...
# A vision emerges!

# %%
import random
import time

answers = ["Danger lurks ahead", "Someone you trust will betray you", "There's no turning back now", "I forsee doom!"]

question = input("🔮 Ask the Fortune Teller a question: ")

print("The Fortune Teller gazes into the crystal ball...")
time.sleep(2)
print("The mists begin to swirl...")
time.sleep(2)
print(f"A vision emerges about: {question}")
time.sleep(1)
print(f"The Fortune Teller says: {random.choice(answers)}")
# Out:
# 🔮 Ask the Fortune Teller a question: jiojo
# The Fortune Teller gazes into the crystal ball...
# The mists begin to swirl...
# A vision emerges about: jiojo
# The Fortune Teller says: Someone you trust will betray you

# %%
name = "Rick"
print(f"Hello, {name}!")
# Out:
# Hello, Rick!
